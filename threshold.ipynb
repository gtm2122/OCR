# %%
import numpy as np
import cv2
from scipy import stats
import os
from matplotlib import pyplot as plt

# %%
img_src = cv2.imread('/data/betty/kmeans/A2C/EQo_1_41_1.jpg')

# %%
#plt.figure(figsize=(20,10))
#plt.imshow(img_src)
#plt.show()

# %%
#img_src

# %%
print np.amax(img_src)
print np.amin(img_src)
# Out:
# 255
# 0

# %%
# black around 20 and white around 235
ret,thresh1 = cv2.threshold(img_src,230,255,cv2.THRESH_BINARY)

# %%
print np.amax(thresh1)
print np.amin(thresh1)
# Out:
# 255
# 0

# %%
#thresh1

# %%
#plt.figure(figsize=(20,10))
#plt.imshow(thresh1)
import scipy.misc
scipy.misc.imsave('/data/gabriel/thresh1.png',thresh1)
#### Do not push this notebook if it has a plot.show() !!
#plt.show()

# %%
from glc import *
#help(glc)

# %%
a = thresh1[0:280,:,0]
#bbox = get_glyphs(scipy.misc.imresize(thresh1[:,:,0],(300,300)))

# %%
bbox = get_glyphs(a)

# %%
#print(len(bbox))

# %%
#print(bbox)

# %%
# for i in bbox:
#     print(i)

# %%
for p in range(0,len(bbox)):

    #count+=1
    #t_img = z_pad(rimg[bbox[p][0]:bbox[p][2],bbox[p][1]:bbox[p][3]])
    t_img = (a[bbox[p][0]:bbox[p][2],bbox[p][1]:bbox[p][3]])
    
    plt.imshow(t_img),plt.show()
    #misc.imsave('/OCR'+str(count)+'.png',t_img)
